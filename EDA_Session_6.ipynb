# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Data File\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include="object").columns
num_columns=visa_df.select_dtypes(exclude="object").columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Encoding**

# %%
- it means convert categorical columns data to numerical data

- because ML models Expect the data should be in Numerical data

- ML models devloped by math algorithms

- it is very very important to apply encoding

- the following method are
# Out:
#   Cell In[6], line 1
#     - it means convert categorical columns data to numerical data
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Map**

# %%
- it is one method to convert cat value to num value

- take one categorical column

- get the unique lables first

- make a dictionary with assign a number to each lable

- for example case_status has two lables

  - certified

  - denied

- assign 0 to certified
# Out:
#   Cell In[7], line 1
#     - it is one method to convert cat value to num value
#                 ^
# SyntaxError: invalid syntax

# %%
#step-1 : read the column
#step-2: get the uni

# %%
visa_df["case_status"].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
#i want to apply the map method for all categorical columns
#step1: we need to get unique label

# %%
unique_labels=visa_df["case_status"].unique()
list1=[i for i in range(len(unique_labels))]
unique_labels,list1
# Out:
# (array(['Denied', 'Certified'], dtype=object), [0, 1])

# %%
unique_labels=sorted(visa_df["case_status"].unique())
list1=[i for i in range(len(unique_labels))]
dict1=dict(zip(unique_labels,list1))
dict1
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
visa_df["case_status"]=visa_df["case_status"].map(dict1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
for i in cat_columns:
    unique_labels=sorted(visa_df[i].unique())
    list1=[i for i in range(len(unique_labels))]
    dict1=dict(zip(unique_labels,list1))
    visa_df[i]=visa_df[i].map(dict1)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **LableenCoder**

# %% [markdown]
# - it is a method to convert cat data to num data
#
# - it is a same way ,how we did in the above
#
# - the for loop map method we explored
#
# - but the lableencoder also do the same
#
# - it is under **sickit-learn** we usually called as **sklearn**
#
# - under skleran we have class called as preprocessing
#
# - because currently we are doing data preprocessing only
#
# - under
#
# - sklearn
#
#   - preprocessing
#
#      - lableencoder
#
# - any sklearn package has three 3 steps:
#
#     - step 1: read the packages
#
#     - step 2:- save the packages
#
#     - step 3 :- apply fit transform on data

# %%
visa_df=pd.read_csv(path)
#step-1
from sklearn.preprocessing import LabelEncoder
#step-2
le=LabelEncoder()
#step-3 apply fit transform on data
visa_df["case_status"]=le.fit_transform(visa_df["case_status"])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
for i in cat_columns:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **fit and transform**

# %%
- fit means devlop the logic
- transform means process the logic

- if we abserve in map method first we devloped dictionary logic

- the we apply that dictionary to column

- devloping the dictionary id kind of fit

- apply the dictonary

# %% [markdown]
# **np.where**

# %% [markdown]
# - using np.where also we can change the categorical data to numerical data
#
# - but np.where is only for binary condition
#
# - np.where is same as if-else
#
# - if condition is true : will apply False value
#
# - so np.where use for only binary labels
#
# - A column should have only two unique label

# %%
visa_df=pd.read_csv(path)
con=visa_df["case_status"]=="Certified"
visa_df["case_status"]=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **One hot encoder**

# %% [markdown]
# - one hot means if one will be ON,another will be OFF
#
# - ON represents with 1
#
# - OFF represents with 0
#
# - For exp. case status has two unique labels
#
#     - Certified
#
#     - Denied
#
# - One hot encoder creates new columns which is equal to number of unique lables
#
# - Foe example case status will create two extra columns
#
#    - case_status_certified
#
#    - case_status_denied
#
# |case_status|case_status_certified|
