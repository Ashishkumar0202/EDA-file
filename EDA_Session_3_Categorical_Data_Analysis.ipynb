# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the packages
#read the data
#cat and numerical column

# %%
path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Data File\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
types=dict(visa_df.dtypes)
#[key if dict(visa_df.dtypes)[i]=='object' for key,value in types.items]

# %%
types=dict(visa_df.dtypes)
cat_columns=[i for i,j in types.items() if j=='object']
num_columns=[i for i,j in types.items() if j!='object']

# %%
visa_df['continent'] #series_type
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df['continent'] #series_type
visa_df[['continent']] #dataframe
visa_df.continent #series
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %% [markdown]
# **Read the multiple columns**

# %% [markdown]
# - when ever we see multiple means recall the list
# - keep the columns in list
# - pass the list

# %%
cols=["continent","case_status"]
visa_df[cols]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %% [markdown]
# **task-1**

# %% [markdown]
# - we want to find the number of applicants continent wise means there are some continent
# - there are Asia continent is there
# - how many applicants are from asea out of 25480

# %% [markdown]
# **Unique**

# %% [markdown]
# - it will provide how many unique items are there in a perticular column

# %%
visa_df["continent"].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
len(visa_df["continent"].unique())
# Out:
# 6

# %% [markdown]
# **N-Unique Method**

# %% [markdown]
# - give count of unique items

# %%
visa_df["continent"].nunique()
# Out:
# 6

# %%
#step-1:-read the data with specific column
#step-2:-apply condition:-
#       when we apply the condition python will give True or False
#step-3:- in order to retrive the True data
#    data_frame_name[con]
visa_df["continent"]
con=visa_df["continent"]=='Asia'
len(visa_df[con])
# Out:
# 16861

# %%
con=visa_df["continent"]=='Asia'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa_df[con])
# Out:
# 16861

# %%
con=visa_df["continent"]=='Asia'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con=visa_df["continent"]=='Africa'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 4         EZYV05    Africa              Master's                  Y
# 18        EZYV19    Africa              Master's                  Y
# 74        EZYV75    Africa              Master's                  Y
# 194      EZYV195    Africa              Master's                  Y
# 242      EZYV243    Africa            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25385  EZYV25386    Africa             Doctorate                  Y
# 25408  EZYV25409    Africa              Master's                  Y
# 25443  EZYV25444    Africa            Bachelor's                  N
# 25446  EZYV25447    Africa              Master's                  N
# 25474  EZYV25475    Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 4                         N             1082         2005
# ...

# %%
con=visa_df["continent"]=='North America'
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 7         EZYV08  North America            Bachelor's                  Y
# 21        EZYV22  North America              Master's                  Y
# 23        EZYV24  North America           High School                  N
# 25        EZYV26  North America              Master's                  N
# 43        EZYV44  North America              Master's                  Y
# ...          ...            ...                   ...                ...
# 25451  EZYV25452  North America           High School                  Y
# 25465  EZYV25466  North America           High School                  N
# 25467  EZYV25468  North America              Master's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
con=visa_df["continent"]=='Europe'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 9         EZYV10    Europe             Doctorate                  Y
# 16        EZYV17    Europe              Master's                  Y
# 24        EZYV25    Europe             Doctorate                  Y
# 36        EZYV37    Europe           High School                  Y
# 37        EZYV38    Europe              Master's                  Y
# ...          ...       ...                   ...                ...
# 25435  EZYV25436    Europe            Bachelor's                  N
# 25448  EZYV25449    Europe             Doctorate                  Y
# 25460  EZYV25461    Europe              Master's                  Y
# 25462  EZYV25463    Europe            Bachelor's                  N
# 25466  EZYV25467    Europe            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 9                         N             2251         1995
# ...

# %%
con=visa_df["continent"]=='South America'
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 121      EZYV122  South America            Bachelor's                  N
# 130      EZYV131  South America           High School                  N
# 171      EZYV172  South America            Bachelor's                  Y
# 188      EZYV189  South America              Master's                  Y
# 224      EZYV225  South America            Bachelor's                  N
# ...          ...            ...                   ...                ...
# 25319  EZYV25320  South America              Master's                  Y
# 25364  EZYV25365  South America            Bachelor's                  Y
# 25413  EZYV25414  South America              Master's                  Y
# 25444  EZYV25445  South America              Master's                  Y
# 25455  EZYV25456  South America            Bachelor's                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
con=visa_df["continent"]=='South America'
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 121      EZYV122  South America            Bachelor's                  N
# 130      EZYV131  South America           High School                  N
# 171      EZYV172  South America            Bachelor's                  Y
# 188      EZYV189  South America              Master's                  Y
# 224      EZYV225  South America            Bachelor's                  N
# ...          ...            ...                   ...                ...
# 25319  EZYV25320  South America              Master's                  Y
# 25364  EZYV25365  South America            Bachelor's                  Y
# 25413  EZYV25414  South America              Master's                  Y
# 25444  EZYV25445  South America              Master's                  Y
# 25455  EZYV25456  South America            Bachelor's                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
con=visa_df["continent"]=='Oceania'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 241      EZYV242   Oceania             Doctorate                  Y
# 288      EZYV289   Oceania            Bachelor's                  N
# 708      EZYV709   Oceania            Bachelor's                  N
# 955      EZYV956   Oceania              Master's                  N
# 960      EZYV961   Oceania            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 24865  EZYV24866   Oceania             Doctorate                  N
# 25150  EZYV25151   Oceania              Master's                  Y
# 25196  EZYV25197   Oceania            Bachelor's                  Y
# 25404  EZYV25405   Oceania             Doctorate                  Y
# 25405  EZYV25406   Oceania              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 241                       N             2871         2009
# ...

# %%
for i in visa_df["continent"].unique():
    con=visa_df["continent"]==i
    count=len(visa_df[con])
    print(f"the number of applicants from {i} is : {count}")
# Out:
# the number of applicants from Asia is : 16861
# the number of applicants from Africa is : 551
# the number of applicants from North America is : 3292
# the number of applicants from Europe is : 3732
# the number of applicants from South America is : 852
# the number of applicants from Oceania is : 192

# %% [markdown]
# **task-2**

# %% [markdown]
# - Now instead of print count,take empty list
# - save the values in a empty list
# - we already has unique continent list
# - we also have count list
# - create a data frame

# %%
continents=visa_df["continent"].unique()
count=[]
for i in visa_df["continent"].unique():
    con=visa_df["continent"]==i
    count.append(len(visa_df[con]))
cols=['continents','Number of Applicants']
continents_df=pd.DataFrame(zip(continents,count),columns=cols)
# continents_df.to_csv("continents_df.csv",index=False)
# continents_df.head()
continents_df.to_csv("continents_df.csv",index=False)

# %% [markdown]
# **value counts**

# %%
l=visa_df[['continent']].value_counts()
l
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
l=[i for i in visa_df["continent"].unique()]
l1=[j for j in visa_df["continent"].value_counts()]
df=pd.DataFrame(zip(l,l1),columns=['continents','Number of Applicants'])
df
# Out:
#       continents  Number of Applicants
# 0           Asia                 16861
# 1         Africa                  3732
# 2  North America                  3292
# 3         Europe                   852
# 4  South America                   551
# 5        Oceania                   192

# %%
path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Data File\bank.csv"

# %%
bank_df=pd.read_csv(path,sep=";")

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# - we create a data frame useing data frame of unique values of a columns and its count
# - we created by our own way,by useing for loop
# - the same operation we can get useing value_count

# %%
cdf=visa_df["continent"].value_counts()
cdf
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
cdf
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
dir(cdf)
# Out:
# ['Africa',
#  'Asia',
#  'Europe',
#  'Oceania',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
type(cdf)
# Out:
# pandas.core.series.Series

# %%
keys=cdf.keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values=cdf.values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
pd.DataFrame(zip(keys,values))
# Out:
#                0      1
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
cdf=visa_df["continent"].value_counts()
keys=cdf.keys()
values=cdf.values
cols=["Lables","count"]
df=pd.DataFrame(zip(keys,values),columns=cols)
df.to_csv("count.csv",index=False)

# %%
df=pd.read_csv("count.csv")
df
# Out:
#           Lables  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
df.dtypes
# Out:
# Lables    object
# count      int64
# dtype: object

# %%
types=dict(visa_df.dtypes)
cat_columns=[i for i,j in types.items() if j=='object']
num_columns=[i for i,j in types.items() if j!='object']

# %%
for i in cat_columns[:1]:
    cfd=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=["Lables","Count"]
    df=pd.DataFrame(zip(keys,values),columns=cols)
    path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\value_count_df"
    df.to_csv(path,index=False)
df
# Out:
#           Lables  Count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
cdf=visa_df[i].value_counts()
keys=cdf.keys()
values=cdf.values
cols=["Lables","count"]
df=pd.DataFrame(zip(keys,values),columns=cols)
path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\value_count_df"
df.to_csv(path,index=False)

# %%
rn=visa_df
rn
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
rn.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat_columns=rn.columns

# %%
for i in cat_columns[1:]:
    cfd=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=["Lables","Count"]
    df=pd.DataFrame(zip(keys,values),columns=cols)
    path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Path"
    df.to_csv(f"{i}1.csv",index=False)

# %%
df.tail()
# Out:
#           Lables  Count
# 25475   EZYV8492      1
# 25476   EZYV8491      1
# 25477   EZYV8490      1
# 25478   EZYV8489      1
# 25479  EZYV25480      1

# %% [markdown]
# **Normalize**

# %% [markdown]
# - Relative frequency table
# - will give percentage of lables in the column

# %%
cdf=visa_df["continent"].value_counts(normalize=True)
round(cdf*100,2)
# Out:
# continent
# Asia             66.17
# Europe           14.65
# North America    12.92
# South America     3.34
# Africa            2.16
# Oceania           0.75
# Name: proportion, dtype: float64

# %% [markdown]
# **Bar Chart**

# %% [markdown]
# - it is the graphical representation of frequency table
# - bar graph is a plot between count and class
# - in order to plot bar chart we required two columns
#      - categorical columns
#     - numerical columns
# - we already created a frequency table for continents.df
#     - here we have cols=["Continents","Number of Applicant"]
#     - categorical column is continents
#      - numerical column is : Number of Applicants
# - Package : matplotlib

# %%
continents_df
# Out:
#       continents  Number of Applicants
# 0           Asia                 16861
# 1         Africa                   551
# 2  North America                  3292
# 3         Europe                  3732
# 4  South America                   852
# 5        Oceania                   192

# %%
import matplotlib.pyplot as plt

# %%
plt.bar('continents','Number of Applicants',data= continents_df);
plt.title('Er Ashish')
plt.xlabel('country_name')
plt.ylabel('Numbers')
# plt.show()
# Out:
# Text(0, 0.5, 'Numbers')

# %%
plt.bar('continents','Number of Applicants',data= continents_df);
# plt.show()

# %% [markdown]
# **Bar chart using Seaborn**

# %% [markdown]
# - we can plot bar chart using many packages
# - one packages matplotlib
# - another is seaborn
# - in matplotlib the method is **plt.bar**
# - in seaborn the method is **countplot**
# - in matplotlib
#   - we will take the raw data
#   - we will create our frequency table i.e. dataframe
#   - we will pass the column1,column2 and dataframe name
# - in seaborn chart
#   - it take direct raw data
#   - we will provide direct column name
#   - we will provide main data frame name

# %%
#continent column====continent_df======plt.bar
#continent column directly======visadf

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5)) #8 units x-axis,sunits y-axis
orde_continents=["Asia","Europe","North America","South America","Africa","Oceania"]
sns.countplot(data=visa_df,x="continent",order=orde_continents)
plt.title("bar chart")
plt.savefig("Continent_bar_chart_using_seaborn")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
visa_df["continent"].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %% [markdown]
# **Task-3**

# %% [markdown]
# **Using For loop plot the Bar chart of all the cat column**
#
# - we can use seaborn and matplotlib
# - Seaborn: countplot requires only raw data, direct column name and main data
# - Matplotlib : Requires frequency table
#  - from row data,will make value counts
#  - from value counts we are making keys and values sepeartly
#  - then we are creating a dataframe
# - Start with seaborn
#   - then we require cat column names
#   - and main data frame
# - start with matplotlib
#  -

# %%
cat_columns[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
for i in cat_columns[1:]:
    cfd=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=["Lables","Count"]
    df=pd.DataFrame(zip(keys,values),columns=cols)
    path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Path"
    df.to_csv(f"{path}\{i}1.csv",index=False)

# %%
import os
x=os.listdir(r'C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Path')
x
# Out:
# ['case_status1.csv',
#  'continent1.csv',
#  'education_of_employee1.csv',
#  'full_time_position1.csv',
#  'has_job_experience1.csv',
#  'region_of_employment1.csv',
#  'requires_job_training1.csv',
#  'unit_of_wage1.csv']

# %%
for i in cat_columns[1:]:
    plt.figure(figsize=(8,5)) #8 units x-axis,sunits y-axis
    orde_continents=visa_df[i].value_counts().keys()
    sns.countplot(data=visa_df,x=i,order=orde_continents)
    plt.title("bar chart")
    plt.xlabel('Label')
    plt.ylabel('count')
    plt.savefig(f"{i}.jpg")
    plt.show()

# %%
cat_columns
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# **How to create a folder**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ASHISH KUMAR\\Data Science Class\\Class notes\\EDA'

# %% [markdown]
# **os.makedirs()**
# - makedirs create a leaf directory
# - means it will take the current working directory and creates one extra folder
# - here my python file in **EDA** folder
# - now i want to create a new folder **graphs_seaborn**
# - which is one step ahead of EDA folder : EDA/graphs_seaborn
# - Pass the full path inside the makedirs()
# - 'C:\\Users\\ASHISH KUMAR\\Python Class\\Class notes\\EDA'

# %%
os.makedirs('ashish')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 os.makedirs('ashish')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'ashish'

# %%
#step-1:
root_directory=os.getcwd()
root_directory

#step-2
new_folder='graphs_seaborn'

#step-3
new_dir=os.path.join(root_directory,new_folder)
new_dir

#step-4:make a dir
os.makedirs(new_dir)

# %%
root_directory=os.getcwd()
root_directory

# %%
new_folder='graphs_seaborn'

# %%
new_dir=os.path.join(root_directory,new_folder)
new_dir

# %%
os.makedirs(new_dir)

# %%
try:
    root_directory=os.getcwd()
    new_folder='graphs_seaborn'
    new_dir=os.path.join(root_directory,new_folder)
    os.makedirs(new_dir)

except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\ASHISH KUMAR\\Data Science Class\\Class notes\\EDA\\graphs_seaborn'

# %%
new_dir
# Out:
# 'C:\\Users\\ASHISH KUMAR\\Data Science Class\\Class notes\\EDA\\graphs_seaborn'

# %%
# for i in cat_columns[1:]:
#     plt.figure(figsize=(8,5)) #8 units x-axis,sunits y-axis
#     orde_continents=visa_df[i].value_counts().keys()
#     sns.countplot(data=visa_df,x=i,order=orde_continents)
#     plt.title("bar chart")
#     path=r'C:\\Users\\ASHISH KUMAR\\Python Class\\Class notes\\EDA\\ashish'
#     plt.savefig(f"{new_dir}\{i}_seaborn.jpg")
#     plt.show

# %% [markdown]
# **Task-4**

# %% [markdown]
# **Using Matplotlib**

# %%
try:
    root_directory=os.getcwd()
    new_folder='graphs_seaborn'
    new_dir=os.path.join(root_directory,new_folder)
    os.makedirs(new_dir)

except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\ASHISH KUMAR\\Data Science Class\\Class notes\\EDA\\graphs_seaborn'

# %%
df=os.listdir(r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA")
df
# Out:
# ['(i).csv',
#  '.ipynb_checkpoints',
#  'ashish',
#  'bank.csv.xlsx',
#  'bank.xlsx.terabox.uploading.cfg',
#  'case_status.csv',
#  'case_status.jpg',
#  'case_status1.csv',
#  'case_status_seaborn.jpg',
#  'Categorical_column_df.csv',
#  'continent.csv',
#  'continent.jpg',
#  'continent1.csv',
#  'Continents_bar_chart.jpg',
#  'continents_df.csv',
#  'Continent_bar_chart_using_seaborn.png',
#  'continent_seaborn.jpg',
#  'count.csv',
#  'Data File',
#  'EDA_Session_1_DataFrame_Operations.ipynb',
#  'EDA_Session_2_Basic_operations_on_Visa_dataset.ipynb',
#  'EDA_Session_3_Categorical_Data_Analysis.ipynb',
#  'EDA_Session_4.ipynb',
#  'education_of_employee.csv',
#  'education_of_employee.jpg',
#  'education_of_employee1.csv',
#  'education_of_employee_seaborn.jpg',
#  'full_time_position.csv',
#  'full_time_position.jpg',
#  'full_time_position1.csv',
#  'full_time_position_seaborn.jpg',
#  'graphs_seaborn',
#  'has_job_experience.csv',
#  'has_job_experience.jpg',
# ...

# %%
for i in dfs:
    df=pd.read_csv(i)
    plt.bar("Label","Count",data=df)
    plt.title("Bar Chart")#Title of graph
    plt.xlabel("Label")#x-axis name
    plt.ylabel("Count") #y-axis name
    plt.savefig(f'{new_dir}\\{i}_matplotlib.jpg')
    plt.show() #show will aviod the

# %%
root_directory=os.getcwd()
new_folder='value_count_df'
dir=os.path.join(root_directory,new_folder)
dir

# %%
for i in dfs:
    df=pd.read_csv(i)
    plt.bar("Label","Count",data=df)
    plt.title("Bar Chart")#Title of graph
    plt.xlabel("Labels")#x-axis name
    plt.ylabel("Count") #y-axis name
    plt.savefig(f"{new_dir}\\{i}_matplotlib.jpg')
    plt.show() #show will aviod the
