# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Data File\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Data File\bank.csv"

# %%
bank_df=pd.read_csv(path,sep=";")

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **Sub Plots**

# %% [markdown]
# - if we have multiple plots when we apply for loop it is giving one by one
# - it hard to see all the graphs
# - it is a kind of a matrix representation
# - we have 2x2 matrix means 4 values,means 4 plots we can plot
# - 1st plot representation with :(2,2,1)
# - 2st plot representation with :(2,2,2)
# - 3st plot representation with :(2,2,3)
# - 4st plot representation with :(2,2,4)

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

#plt.subplot(2,2,)
# Out:
# <Axes: >

# %%
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
for i in range(1,8):
    plt.subplot(3,3,i)

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
plt.subplot(2,1,1)
plt.subplot(2,1,2)
# Out:
# <Axes: >

# %%
#read the data take two columns 
#1.continent 2. case status
#draw the seaborn individually

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.countplot(x="continent",data=visa_df)
plt.subplot(1,2,2)
sns.countplot(x="case_status",data=visa_df)
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %% [markdown]
# **Tas-2**
#
# - continent,has_job_experience,requires_job_training,case_status

# %%
plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
sns.countplot(x="continent",data=visa_df)
plt.title("continent_bar_chart")
plt.subplot(2,2,2)
sns.countplot(x="has_job_experience",data=visa_df)
plt.title("has_job_experience_bar_chart")
plt.subplot(2,2,3)
sns.countplot(x="requires_job_training",data=visa_df)
plt.title("requires_job_training_bar_chart")
plt.subplot(2,2,4)
sns.countplot(x="case_status",data=visa_df)
plt.title("case_status_bar_chart")
# Out:
# Text(0.5, 1.0, 'case_status_bar_chart')

# %% [markdown]
# **Task-3**

# %% [markdown]
# - take cat columns,slice from index 1, avoid case_id
# - we have 8 plots,so the grid is 3x3
# - for loop should iterate length of cat_cols[1:]

# %%
types=dict(visa_df.dtypes)
cat_columns=[i for i,j in types.items() if j=='object']
num_columns=[i for i,j in types.items() if j!='object']
cat_columns,num_columns
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
plt.figure(figsize=(16,14))
cols=cat_columns[1:]
for i in range (len(cols)):
    plt.subplot(3,3,i+1)
    sns.countplot(x=cols[i],data=visa_df)

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)
plt.subplot(3,3,3)
plt.subplot(3,3,4)
plt.subplot(3,3,5)
plt.subplot(3,3,6)
plt.subplot(3,3,7)
plt.subplot(3,3,8)
plt.subplot(3,3,9)
# Out:
# <Axes: >

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Method-3**

# %%
path=r"C:\Users\ASHISH KUMAR\Data Science Class\Class notes\EDA\Data File\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
types=dict(visa_df.dtypes)
cat_columns=[i for i,j in types.items() if j=='object']
num_columns=[i for i,j in types.items() if j!='object']

# %%
cat_columns
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num_columns
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
l=visa_df[['continent']].value_counts()
l
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
l=[i for i in visa_df["continent"].unique()]
l1=[j for j in visa_df["continent"].value_counts()]
df=pd.DataFrame(zip(l,l1),columns=['continents','Number of Applicants'])
df
# Out:
#       continents  Number of Applicants
# 0           Asia                 16861
# 1         Africa                  3732
# 2  North America                  3292
# 3         Europe                   852
# 4  South America                   551
# 5        Oceania                   192

# %%
new_variable=visa_df['continent'].value_counts()
new_variable.plot(kind='bar')
new_variable.bar_label(new_variable.containent)
plt.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9172\312236165.py in ?()
#       1 new_variable=visa_df['continent'].value_counts()
#       2 new_variable.plot(kind='bar')
# ----> 3 new_variable.bar_label(new_variable.containent)
#       4 plt.count()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'bar_label'

# %%
new_variable=visa_df['continent'].value_counts()
ax=new_variable.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# **All Three together**

# %% [markdown]
# **Pie Chart**

# %% [markdown]
# - pie chart is a 360 degree view
# - it is under matplotlib package
# - it will take keys and values
# - that we will get fro value counts

# %%
#step-1: get keys from continent value count
#step-2 : get values from continent value counts
#step-3 : plt.pie verify the arguments
#   which argument take values and keys

# %%
visa_df

# %%
cdf=visa_df["continent"].value_counts()
cdf
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
keys=cdf.keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values=cdf.values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
keys=visa_df["continent"].value_counts().keys()
values=visa_df["continent"].value_counts().values

# %%
plt.pie(values,labels=keys,autopct="%0.1f%%")
plt.show()
